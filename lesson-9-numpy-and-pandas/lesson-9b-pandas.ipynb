# %% [markdown]
# # Lesson 9b: Pandas

# %% [markdown]
# Version 1.1. Prepared by [Makzan](https://makzan.net). Updated at 2021 March.

# %% [markdown]
# Pandas stands for Python Data Analysis Library. It makes use of Series (Like a Numpy Array) and DataFrame (tabular data). In this lesson, we will learn the basic data processing, calculation and filtering by using Pandas.

# %% [markdown]
# - [Is student passed?](#Is-student-passed?)
# - [Accessing the column](#Accessing-the-column)
# - [Reading Excel](#Reading-Excel)
# - [Reading CSV](#Reading-CSV)
# - [Fetching CSV from Wikipedia](#Fetching-CSV-from-Wikipedia)
# - [Lab 4: Olymnic Games medal table](#Lab-4:-All-time-Olympic-Games-medal-table)

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Is student passed?
#
# Remember the `pass_or_fail` function we defined in lesson 2? Now we can further process this example with Pandas and its DataFrame.

# %%
# Apply label to data
def pass_or_fail(x):
    if x >= 60:
        return True
    return False

def grading(x):
    if x >= 90:
        return 'A'
    elif x >= 80:
        return 'B'
    elif x >= 70:
        return 'C'
    elif x >= 60:
        return 'D'
    else:
        return 'F'

# %%
# Prepare the data
data = [50, 60, 20, 50, 88, 45, 63, 59]

# %% [markdown]
# Given the data list, we can convert it into DataFrame

# %%
# Where is the pass and fail?
df = pd.DataFrame(data, columns=['Score'])
df
# Out:
#    Score
# 0     50
# 1     60
# 2     20
# 3     50
# 4     88
# 5     45
# 6     63
# 7     59

# %% [markdown]
# We can create extra column to indicate if the score is passed.

# %%
df['Is Passed'] = df['Score'].apply(pass_or_fail)
df
# Out:
#    Score  Is Passed Grade
# 0     50      False     F
# 1     60       True     D
# 2     20      False     F
# 3     50      False     F
# 4     88       True     B
# 5     45      False     F
# 6     63       True     D
# 7     59      False     F

# %%
df['Grade'] = df['Score'].apply(grading)
df
# Out:
#    Score  Is Passed Grade
# 0     50      False     F
# 1     60       True     D
# 2     20      False     F
# 3     50      False     F
# 4     88       True     B
# 5     45      False     F
# 6     63       True     D
# 7     59      False     F

# %% [markdown]
# By using Boolean filtering, we can list only the data that meet the condition.

# %%
df[ (df['Score']>=60) & (df['Score']<=80) ]
# Out:
#    Score  Is Passed Grade
# 1     60       True     D
# 6     63       True     D

# %% [markdown]
# Next, we will load the students dictionary from lesson 2.

# %%
students = [
    {'name': 'Thomas', 'score': 65},
    {'name': 'Alan', 'score': 95},
    {'name': 'Jane', 'score': 85},
    {'name': 'Susan', 'score': 75},
    {'name': 'Chris', 'score': 45}
]

# %% [markdown]
# We convert the dictionary into DataFrame. Pandas will take care of the column name automatically.

# %%
df = pd.DataFrame(students)
df
# Out:
#      name  score
# 0  Thomas     65
# 1    Alan     95
# 2    Jane     85
# 3   Susan     75
# 4   Chris     45

# %% [markdown]
# Same as the example above, we apply the `pass_or_fail` function to create a new column with Boolean.

# %%
df['Is Passed'] = df['score'].apply(pass_or_fail)
df
# Out:
#      name  score  Is Passed
# 0  Thomas     65       True
# 1    Alan     95       True
# 2    Jane     85       True
# 3   Susan     75       True
# 4   Chris     45      False

# %% [markdown]
# We can generate a new DataFrame with only the passed records.

# %%
df_passed = df[df["Is Passed"]]
df_passed
# Out:
#      name  score  Is Passed
# 0  Thomas     65       True
# 1    Alan     95       True
# 2    Jane     85       True
# 3   Susan     75       True

# %% [markdown]
# We can save the processed tabular data into Excel by using `to_excel`.

# %%
df_passed.to_excel("Students Passed.xlsx")

# %% [markdown]
# ## Accessing the column

# %% [markdown]
# We can get the name of students who passed.

# %%
df[df["Is Passed"]]["name"]
# Out:
# 0    Thomas
# 1      Alan
# 2      Jane
# 3     Susan
# Name: name, dtype: object

# %% [markdown]
# An example of outputing the result.

# %%
count_of_passed = len(df[df["Is Passed"]])
result = f"We have total {len(df)} students, {count_of_passed} of them passed."
print(result)
# Out:
# We have total 5 students, 4 of them passed.

# %%
names = ', '.join(df[df["Is Passed"]]["name"])
names = f"They are {names}."

print(names)
# Out:
# They are Thomas, Alan, Jane, Susan.

# %% [markdown]
# ## Reading Excel

# %%
df = pd.read_excel('visitors.xlsx')
df
# Out:
#     Time  Visitors
# 0      1         2
# 1      2         0
# 2      3         1
# 3      4         3
# 4      5         0
# 5      6         8
# 6      7        32
# 7      8        48
# 8      9        21
# 9     10        10
# 10    11         9
# 11    12        47
# 12    13        42
# 13    14        15
# 14    15        11
# 15    16        12
# 16    17        19
# 17    18        55
# 18    19        57
# 19    20        55
# 20    21        32
# 21    22        24
# 22    23        11
# 23    24         4

# %%
df.head()
# Out:
#    Time  Visitors
# 0     1         2
# 1     2         0
# 2     3         1
# 3     4         3
# 4     5         0

# %%
df.tail()
# Out:
#     Time  Visitors
# 19    20        55
# 20    21        32
# 21    22        24
# 22    23        11
# 23    24         4

# %%
df['Visitors']
# Out:
# 0      2
# 1      0
# 2      1
# 3      3
# 4      0
# 5      8
# 6     32
# 7     48
# 8     21
# 9     10
# 10     9
# 11    47
# 12    42
# 13    15
# 14    11
# 15    12
# 16    19
# 17    55
# 18    57
# 19    55
# 20    32
# 21    24
# 22    11
# 23     4
# Name: Visitors, dtype: int64

# %% [markdown]
# Which hours do we have more than 30 visitors?

# %%
df[ df['Visitors'] > 30 ]
# Out:
#     Time  Visitors
# 6      7        32
# 7      8        48
# 11    12        47
# 12    13        42
# 17    18        55
# 18    19        57
# 19    20        55
# 20    21        32

# %% [markdown]
# We can create new Boolean column with condition.

# %%
df['Good Timing'] = df['Visitors']>30

# %%
df
# Out:
#     Time  Visitors  Good Timing
# 0      1         2        False
# 1      2         0        False
# 2      3         1        False
# 3      4         3        False
# 4      5         0        False
# 5      6         8        False
# 6      7        32         True
# 7      8        48         True
# 8      9        21        False
# 9     10        10        False
# 10    11         9        False
# 11    12        47         True
# 12    13        42         True
# 13    14        15        False
# 14    15        11        False
# 15    16        12        False
# 16    17        19        False
# 17    18        55         True
# 18    19        57         True
# 19    20        55         True
# 20    21        32         True
# 21    22        24        False
# 22    23        11        False
# 23    24         4        False

# %%
df[df['Good Timing']]
# Out:
#     Time  Visitors  Good Timing
# 6      7        32         True
# 7      8        48         True
# 11    12        47         True
# 12    13        42         True
# 17    18        55         True
# 18    19        57         True
# 19    20        55         True
# 20    21        32         True

# %% [markdown]
# ## Reading CSV

# %%
df = pd.read_csv('visitors.csv', delimiter=',', names=('date','visitors'))

df.head()
# Out:
#          date  visitors
# 0  2018-12-18        22
# 1  2018-12-17         0
# 2  2018-12-16         4
# 3  2018-12-15       218
# 4  2018-12-14        11

# %%
df['date'].head()
# Out:
# 0    2018-12-18
# 1    2018-12-17
# 2    2018-12-16
# 3    2018-12-15
# 4    2018-12-14
# Name: date, dtype: object

# %% [markdown]
# ## Fetching CSV from Wikipedia

# %% [markdown]
# We can convert the data table into CSV by using https://wikitable2csv.ggor.de

# %% [markdown]
# For example, we can download the All-time Olympic Games medal table from Wikipedia:
#
# https://en.wikipedia.org/wiki/All-time_Olympic_Games_medal_table

# %% [markdown]
# We can load the converted CSV directly into pandas and process the data set. Alternatively, we can clean up the CSV a little bit before loading it into pandas.
#
# For instance, we can give each column a readable name in header. We can also convert thousands with comma too.

# %% [markdown]
# ## Lab 4: All-time Olympic Games medal table

# %% [markdown]
# We have prepared a `table-1-olympics.csv` file with basic format processed.

# %%
df = pd.read_csv('table-1-olympics.csv')
df = df[:-1] # Remove the last row of data
df.head()
# Out:
#                       Team  Summer Games Gold Silver Bronze Total  \
# 0        Afghanistan (AFG)            14    0      0      2     2
# 1            Algeria (ALG)            13    5      4      8    17
# 2          Argentina (ARG)            24   21     25     28    74
# 3            Armenia (ARM)             6    2      6      6    14
# 4  Australasia (ANZ) [ANZ]             2    3      4      5    12
#
#    Winter Games  Gold.1  Silver.1  Bronze.1 Total.1  Combined Participated  \
# 0             0       0         0         0       0                     14
# 1             3       0         0         0       0                     16
# 2            19       0         0         0       0                     43
# 3             7       0         0         0       0                     13
# 4             0       0         0         0       0                      2
#
#   Combined Gold Combined Silver Combined Bronze Combined Total
# 0             0               0               2              2
# 1             5               4               8             17
# 2            21              25              28             74
# 3             2               6               6             14
# 4             3               4               5             12

# %%
df.shape
# Out:
# (152, 16)

# %% [markdown]
# By checking the `dtype`, we find that the data in "O" instead of "Int". "O" stands for Object because it is treated as String.

# %%
df['Gold'].dtype
# Out:
# dtype('O')

# %%
df['Total'].dtype
# Out:
# dtype('O')

# %% [markdown]
# We can convert the dtype by using `astype`.

# %%
df['Total'] = df['Total'].astype(int)

# %%
df['Total'].dtype
# Out:
# dtype('int32')

# %% [markdown]
# Now the team name is not quite readable. There are extra symbols and footnote indicators.
#
# We can clean up `Team` name and replace space into underscore:

# %%
df["Team"] = df["Team"].apply(lambda x: x.split("(")[0].strip().replace(" ","_"))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Team'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-fee7b6e72e33> in <module>
# ----> 1 df["Team"] = df["Team"].apply(lambda x: x.split("(")[0].strip().replace(" ","_"))
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Team'

# %%
df.head()
# Out:
#           Team  Summer Games Gold Silver Bronze  Total  Winter Games  Gold.1  \
# 0  Afghanistan            14    0      0      2      2             0       0
# 1      Algeria            13    5      4      8     17             3       0
# 2    Argentina            24   21     25     28     74            19       0
# 3      Armenia             6    2      6      6     14             7       0
# 4  Australasia             2    3      4      5     12             0       0
#
#    Silver.1  Bronze.1 Total.1  Combined Participated Combined Gold  \
# 0         0         0       0                     14             0
# 1         0         0       0                     16             5
# 2         0         0       0                     43            21
# 3         0         0       0                     13             2
# 4         0         0       0                      2             3
#
#   Combined Silver Combined Bronze Combined Total
# 0               0               2              2
# 1               4               8             17
# 2              25              28             74
# 3               6               6             14
# 4               4               5             12

# %% [markdown]
# Set the Team name as dataframe index:

# %%
df.set_index("Team", inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Team'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-60845a9801a6> in <module>
# ----> 1 df.set_index("Team", inplace=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4176                 names.append(None)
#    4177             else:
# -> 4178                 level = frame[col]._values
#    4179                 names.append(col)
#    4180                 if drop:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Team'

# %% [markdown]
# Make sure all numbers in the dataframe are numeric:

# %%
df = df.astype(int)
df
# Out:
#                                   Summer Games  Gold  Silver  Bronze  Total  \
# Team
# Afghanistan                                 14     0       0       2      2
# Algeria                                     13     5       4       8     17
# Argentina                                   24    21      25      28     74
# Armenia                                      6     2       6       6     14
# Australasia                                  2     3       4       5     12
# Australia                                   26   147     163     187    497
# Austria                                     27    18      33      36     87
# Azerbaijan                                   6     7      11      25     43
# Bahamas                                     16     6       2       6     14
# Bahrain                                      9     2       1       0      3
# Barbados                                    12     0       0       1      1
# Belarus                                      6    12      27      39     78
# Belgium                                     26    40      53      55    148
# Bermuda                                     18     0       0       1      1
# Bohemia                                      3     0       1       3      4
# Botswana                                    10     0       1       0      1
# Brazil                                      22    30      36      63    129
# British_West_Indies                          1     0       0       2      2
# Bulgaria                                    20    51      87      80    218
# Burundi                                      6     1       1       0      2
# Cameroon                                    14     3       1       2      6
# Canada                                      26    64     102     136    302
# Chile                                       23     2       7       4     13
# China                                       10   224     167     155    546
# Colombia                                    19     5       9      14     28
# Costa_Rica                                  15     1       1       2      4
# Ivory_Coast                                 13     1       1       1      3
# Croatia                                      7    11      10      12     33
# Cuba                                        20    78      68      80    226
# Cyprus                                      10     0       1       0      1
# ...                                        ...   ...     ...     ...    ...
# Suriname                                    12     1       0       1      2
# Sweden                                      27   145     170     179    494
# Switzerland                                 28    50      75      67    192
# Syria                                       13     1       1       1      3
# Chinese_Taipei                              14     5       7      12     24
# Tajikistan                                   6     1       1       2      4
# Tanzania                                    13     0       2       0      2
# Thailand                                    16     9       8      16     33
# Togo                                        10     0       0       1      1
# Tonga                                        9     0       1       0      1
# Trinidad_and_Tobago                         17     3       5      11     19
# Tunisia                                     14     4       2       7     13
# Turkey                                      22    39      24      28     91
# Uganda                                      15     2       3       2      7
# Ukraine                                      6    35      30      56    121
# United_Arab_Emirates                         9     1       0       1      2
# United_States                               27  1022     795     705   2522
# Uruguay                                     21     2       2       6     10
# Uzbekistan                                   6     8       6      17     31
# Venezuela                                   18     2       4       9     15
# Vietnam                                     15     1       3       0      4
# Virgin_Islands                              12     0       1       0      1
# Yugoslavia                                  18    28      31      31     90
# Zambia                                      13     0       1       1      2
# Zimbabwe                                    13     3       4       1      8
# Unified_Team                                 1    45      38      29    112
# Independent_Olympic_Athletes                 3     1       0       1      2
# Independent_Olympic_Participants             1     0       1       2      3
# Olympic_Athletes_from_Russia                 0     0       0       0      0
# Mixed_team                                   3     8       5       4     17
#
#                                   Winter Games  Gold.1  Silver.1  Bronze.1  \
# Team
# Afghanistan                                  0       0         0         0
# Algeria                                      3       0         0         0
# Argentina                                   19       0         0         0
# Armenia                                      7       0         0         0
# Australasia                                  0       0         0         0
# Australia                                   19       5         5         5
# Austria                                     23      64        81        87
# Azerbaijan                                   6       0         0         0
# Bahamas                                      0       0         0         0
# Bahrain                                      0       0         0         0
# Barbados                                     0       0         0         0
# Belarus                                      7       8         5         5
# Belgium                                     21       1         2         3
# Bermuda                                      8       0         0         0
# Bohemia                                      0       0         0         0
# Botswana                                     0       0         0         0
# Brazil                                       8       0         0         0
# British_West_Indies                          0       0         0         0
# Bulgaria                                    20       1         2         3
# Burundi                                      0       0         0         0
# Cameroon                                     1       0         0         0
# Canada                                      23      73        64        62
# Chile                                       17       0         0         0
# China                                       11      13        28        21
# Colombia                                     2       0         0         0
# Costa_Rica                                   6       0         0         0
# Ivory_Coast                                  0       0         0         0
# Croatia                                      8       4         6         1
# Cuba                                         0       0         0         0
# Cyprus                                      11       0         0         0
# ...                                        ...     ...       ...       ...
# Suriname                                     0       0         0         0
# Sweden                                      23      57        46        55
# Switzerland                                 23      56        45        52
# Syria                                        0       0         0         0
# Chinese_Taipei                              12       0         0         0
# Tajikistan                                   4       0         0         0
# Tanzania                                     0       0         0         0
# Thailand                                     4       0         0         0
# Togo                                         2       0         0         0
# Tonga                                        2       0         0         0
# Trinidad_and_Tobago                          3       0         0         0
# Tunisia                                      0       0         0         0
# Turkey                                      17       0         0         0
# Uganda                                       0       0         0         0
# Ukraine                                      7       3         1         4
# United_Arab_Emirates                         0       0         0         0
# United_States                               23     105       112        88
# Uruguay                                      1       0         0         0
# Uzbekistan                                   7       1         0         0
# Venezuela                                    4       0         0         0
# Vietnam                                      0       0         0         0
# Virgin_Islands                               7       0         0         0
# Yugoslavia                                  16       0         3         1
# Zambia                                       0       0         0         0
# Zimbabwe                                     1       0         0         0
# Unified_Team                                 1       9         6         8
# Independent_Olympic_Athletes                 0       0         0         0
# Independent_Olympic_Participants             0       0         0         0
# Olympic_Athletes_from_Russia                 1       2         6         9
# Mixed_team                                   0       0         0         0
#
#                                   Total.1  Combined Participated  \
# Team
# Afghanistan                             0                     14
# Algeria                                 0                     16
# Argentina                               0                     43
# Armenia                                 0                     13
# Australasia                             0                      2
# Australia                              15                     45
# Austria                               232                     50
# Azerbaijan                              0                     12
# Bahamas                                 0                     16
# Bahrain                                 0                      9
# Barbados                                0                     12
# Belarus                                18                     13
# Belgium                                 6                     47
# Bermuda                                 0                     26
# Bohemia                                 0                      3
# Botswana                                0                     10
# Brazil                                  0                     30
# British_West_Indies                     0                      1
# Bulgaria                                6                     40
# Burundi                                 0                      6
# Cameroon                                0                     15
# Canada                                199                     49
# Chile                                   0                     40
# China                                  62                     21
# Colombia                                0                     21
# Costa_Rica                              0                     21
# Ivory_Coast                             0                     13
# Croatia                                11                     15
# Cuba                                    0                     20
# Cyprus                                  0                     21
# ...                                   ...                    ...
# Suriname                                0                     12
# Sweden                                158                     50
# Switzerland                           153                     51
# Syria                                   0                     13
# Chinese_Taipei                          0                     26
# Tajikistan                              0                     10
# Tanzania                                0                     13
# Thailand                                0                     20
# Togo                                    0                     12
# Tonga                                   0                     11
# Trinidad_and_Tobago                     0                     20
# Tunisia                                 0                     14
# Turkey                                  0                     39
# Uganda                                  0                     15
# Ukraine                                 8                     13
# United_Arab_Emirates                    0                      9
# United_States                         305                     50
# Uruguay                                 0                     22
# Uzbekistan                              1                     13
# Venezuela                               0                     22
# Vietnam                                 0                     15
# Virgin_Islands                          0                     19
# Yugoslavia                              4                     34
# Zambia                                  0                     13
# Zimbabwe                                0                     14
# Unified_Team                           23                      2
# Independent_Olympic_Athletes            0                      3
# Independent_Olympic_Participants        0                      1
# Olympic_Athletes_from_Russia           17                      1
# Mixed_team                              0                      3
#
#                                   Combined Gold  Combined Silver  \
# Team
# Afghanistan                                   0                0
# Algeria                                       5                4
# Argentina                                    21               25
# Armenia                                       2                6
# Australasia                                   3                4
# Australia                                   152              168
# Austria                                      82              114
# Azerbaijan                                    7               11
# Bahamas                                       6                2
# Bahrain                                       2                1
# Barbados                                      0                0
# Belarus                                      20               32
# Belgium                                      41               55
# Bermuda                                       0                0
# Bohemia                                       0                1
# Botswana                                      0                1
# Brazil                                       30               36
# British_West_Indies                           0                0
# Bulgaria                                     52               89
# Burundi                                       1                1
# Cameroon                                      3                1
# Canada                                      137              166
# Chile                                         2                7
# China                                       237              195
# Colombia                                      5                9
# Costa_Rica                                    1                1
# Ivory_Coast                                   1                1
# Croatia                                      15               16
# Cuba                                         78               68
# Cyprus                                        0                1
# ...                                         ...              ...
# Suriname                                      1                0
# Sweden                                      202              216
# Switzerland                                 106              120
# Syria                                         1                1
# Chinese_Taipei                                5                7
# Tajikistan                                    1                1
# Tanzania                                      0                2
# Thailand                                      9                8
# Togo                                          0                0
# Tonga                                         0                1
# Trinidad_and_Tobago                           3                5
# Tunisia                                       4                2
# Turkey                                       39               24
# Uganda                                        2                3
# Ukraine                                      38               31
# United_Arab_Emirates                          1                0
# United_States                              1127              907
# Uruguay                                       2                2
# Uzbekistan                                    9                6
# Venezuela                                     2                4
# Vietnam                                       1                3
# Virgin_Islands                                0                1
# Yugoslavia                                   28               34
# Zambia                                        0                1
# Zimbabwe                                      3                4
# Unified_Team                                 54               44
# Independent_Olympic_Athletes                  1                0
# Independent_Olympic_Participants              0                1
# Olympic_Athletes_from_Russia                  2                6
# Mixed_team                                    8                5
#
#                                   Combined Bronze  Combined Total
# Team
# Afghanistan                                     2               2
# Algeria                                         8              17
# Argentina                                      28              74
# Armenia                                         6              14
# Australasia                                     5              12
# Australia                                     192             512
# Austria                                       123             319
# Azerbaijan                                     25              43
# Bahamas                                         6              14
# Bahrain                                         0               3
# Barbados                                        1               1
# Belarus                                        44              96
# Belgium                                        58             154
# Bermuda                                         1               1
# Bohemia                                         3               4
# Botswana                                        0               1
# Brazil                                         63             129
# British_West_Indies                             2               2
# Bulgaria                                       83             224
# Burundi                                         0               2
# Cameroon                                        2               6
# Canada                                        198             501
# Chile                                           4              13
# China                                         176             608
# Colombia                                       14              28
# Costa_Rica                                      2               4
# Ivory_Coast                                     1               3
# Croatia                                        13              44
# Cuba                                           80             226
# Cyprus                                          0               1
# ...                                           ...             ...
# Suriname                                        1               2
# Sweden                                        234             652
# Switzerland                                   119             345
# Syria                                           1               3
# Chinese_Taipei                                 12              24
# Tajikistan                                      2               4
# Tanzania                                        0               2
# Thailand                                       16              33
# Togo                                            1               1
# Tonga                                           0               1
# Trinidad_and_Tobago                            11              19
# Tunisia                                         7              13
# Turkey                                         28              91
# Uganda                                          2               7
# Ukraine                                        60             129
# United_Arab_Emirates                            1               2
# United_States                                 793            2827
# Uruguay                                         6              10
# Uzbekistan                                     17              32
# Venezuela                                       9              15
# Vietnam                                         0               4
# Virgin_Islands                                  0               1
# Yugoslavia                                     32              94
# Zambia                                          1               2
# Zimbabwe                                        1               8
# Unified_Team                                   37             135
# Independent_Olympic_Athletes                    1               2
# Independent_Olympic_Participants                2               3
# Olympic_Athletes_from_Russia                    9              17
# Mixed_team                                      4              17
#
# [152 rows x 15 columns]

# %% [markdown]
# We can inspect the column names by using `df.columns`

# %%
df.columns
# Out:
# Index(['Summer Games', 'Gold', 'Silver', 'Bronze', 'Total', 'Winter Games',
#        'Gold.1', 'Silver.1', 'Bronze.1', 'Total.1', 'Combined Participated',
#        'Combined Gold', 'Combined Silver', 'Combined Bronze',
#        'Combined Total'],
#       dtype='object')

# %% [markdown]
# |Expected result|
# |---|
# |Index(['Summer Games', 'Gold', 'Silver', 'Bronze', 'Total', 'Winter Games',
#        'Gold.1', 'Silver.1', 'Bronze.1', 'Total.1', 'Combined Participated',
#        'Combined Gold', 'Combined Silver', 'Combined Bronze',
#        'Combined Total'],
#       dtype='object')|

# %% [markdown]
# We can access a particular row of data by using `iloc`

# %%
df.iloc[16]
# Out:
# Summer Games              22
# Gold                      30
# Silver                    36
# Bronze                    63
# Total                    129
# Winter Games               8
# Gold.1                     0
# Silver.1                   0
# Bronze.1                   0
# Total.1                    0
# Combined Participated     30
# Combined Gold             30
# Combined Silver           36
# Combined Bronze           63
# Combined Total           129
# Name: Brazil, dtype: object

# %% [markdown]
# We can also access a particular row of data by using the index label `df.loc["Brazil"]`.

# %% [markdown]
# What is the Olymnpic Medal data from China?

# %%
df.loc['China']
# Out:
# Summer Games              10
# Gold                     224
# Silver                   167
# Bronze                   155
# Total                    546
# Winter Games              11
# Gold.1                    13
# Silver.1                  28
# Bronze.1                  21
# Total.1                   62
# Combined Participated     21
# Combined Gold            237
# Combined Silver          195
# Combined Bronze          176
# Combined Total           608
# Name: China, dtype: object

# %% [markdown]
# |Expected result|
# |---|
# |Summer Games              10
# Gold                     224
# Silver                   167
# Bronze                   155
# Total                    546
# Winter Games              11
# Gold.1                    13
# Silver.1                  28
# Bronze.1                  21
# Total.1                   62
# Combined Participated     21
# Combined Gold            237
# Combined Silver          195
# Combined Bronze          176
# Combined Total           608
# Name: China, dtype: int32|

# %% [markdown]
# How many gold medal China won in Summer Olymnpics?

# %%
df.loc['China']['Gold']
# Out:
# '224'

# %% [markdown]
# |Expected result|
# |---|
# |224|

# %% [markdown]
# We can get the rank of gold medal list by using `df.sort_values`.

# %%
df.sort_values(by="Gold", ascending=False)[:10]
# Out:
#              Summer Games Gold Silver Bronze  Total  Winter Games  Gold.1  \
# Team
# South_Korea            17   90     87     90    267            18      31
# Thailand               16    9      8     16     33             4       0
# India                  24    9      7     12     28            10       0
# Ireland                21    9     10     12     31             7       0
# Estonia                12    9      9     16     34            10       4
# Slovakia                6    9     12      7     28             7       3
# Romania                21   89     95    122    306            21       0
# Netherlands            26   85     92    108    285            21      45
# Georgia                 6    8      7     17     32             7       0
# Mixed_team              3    8      5      4     17             0       0
#
#              Silver.1  Bronze.1 Total.1  Combined Participated Combined Gold  \
# Team
# South_Korea        25        14      70                     35           121
# Thailand            0         0       0                     20             9
# India               0         0       0                     34             9
# Ireland             0         0       0                     28             9
# Estonia             2         1       7                     22            13
# Slovakia            4         1       8                     13            12
# Romania             0         1       1                     42            89
# Netherlands        44        41     130                     47           130
# Georgia             0         0       0                     13             8
# Mixed_team          0         0       0                      3             8
#
#             Combined Silver Combined Bronze Combined Total
# Team
# South_Korea             112             104            337
# Thailand                  8              16             33
# India                     7              12             28
# Ireland                  10              12             31
# Estonia                  11              17             41
# Slovakia                 16               8             36
# Romania                  95             123            307
# Netherlands             136             149            415
# Georgia                   7              17             32
# Mixed_team                5               4             17

# %% [markdown]
# How many teams earn gold medals in both summer Olympics and winder Olympics?

# %%
len(df[(df["Gold"] > 0) & (df["Gold.1"] > 0)])
# Out:
# 38

# %% [markdown]
# Which teams are they?

# %%
df[(df["Gold"] > 0) & (df["Gold.1"] > 0)][['Gold','Gold.1']]
# Out:
#                         Gold  Gold.1
# Team
# Australia                147       5
# Austria                   18      64
# Belarus                   12       8
# Belgium                   40       1
# Bulgaria                  51       1
# Canada                    64      73
# China                    224      13
# Croatia                   11       4
# Czech_Republic            15       9
# Czechoslovakia            49       2
# Estonia                    9       4
# Finland                  101      43
# France                   212      36
# Germany                  191      92
# United_Team_of_Germany    28       8
# East_Germany             153      39
# West_Germany              56      11
# Great_Britain            263      11
# Hungary                  175       1
# Italy                    206      40
# Japan                    142      14
# Kazakhstan                15       1
# South_Korea               90      31
# Latvia                     3       1
# Netherlands               85      45
# Norway                    56     132
# Poland                    68       7
# Russia                   148      47
# Soviet_Union             395      78
# Slovakia                   9       3
# Slovenia                   5       2
# Spain                     45       1
# Sweden                   145      57
# Switzerland               50      56
# Ukraine                   35       3
# United_States           1022     105
# Uzbekistan                 8       1
# Unified_Team              45       9

# %% [markdown]
# How about the team that wins gold medals in winter Olympics but not summer Olympics?

# %%
a = df.index[(df['Gold.1'] > 0) & (df['Gold'] <= 0)]
list(df.index[(df['Gold.1'] > 0) & (df['Gold'] <= 0)])
# Out:
# ['Liechtenstein', 'Olympic_Athletes_from_Russia']

# %% [markdown]
# |Expected result|
# |---|
# |['Liechtenstein', 'Olympic_Athletes_from_Russia']|

# %% [markdown]
# ## Example: Reading DSEC Visitors.xlsx

# %%
df = pd.read_excel("dsec_visitors.xlsx", skiprows=4, skipfooter=4)
df.columns

df = df.rename(columns={
    "Unnamed: 0": "時期",
    "按證件簽發地統計之旅客 b": "按證件簽發地統計之旅客",
    "按證件簽發地統計之留宿旅客 b": "按證件簽發地統計之留宿旅客",
    "按證件簽發地統計之不過夜旅客 b": "按證件簽發地統計之不過夜旅客"
})
df = df.drop(columns=["Unnamed: 2", "Unnamed: 4", "Unnamed: 6"])
df = df[1:]
df.head()
# Out:
#         時期 按證件簽發地統計之旅客 按證件簽發地統計之留宿旅客 按證件簽發地統計之不過夜旅客
# 1  2011年1月         1.1           2.2            0.2
# 2  2011年2月           1             2            0.2
# 3  2011年3月           1           2.1            0.2
# 4  2011年4月           1             2            0.2
# 5  2011年5月         1.1           2.1            0.2

# %%
def year_from_dsec_date_period(period):
    """Convert 2011年5月 into 2011"""
    return int(period.split("年")[0])
def month_from_dsec_date_period(period):
    """Convert 2011年5月 into 2011"""
    return int(period.split("年")[1].replace("月",""))

# %%
df["Year"] = df["時期"].apply(year_from_dsec_date_period)
df["Month"] = df["時期"].apply(month_from_dsec_date_period)
df
# Out:
#            時期 按證件簽發地統計之旅客 按證件簽發地統計之留宿旅客 按證件簽發地統計之不過夜旅客  Year  Month
# 1     2011年1月         1.1           2.2            0.2  2011      1
# 2     2011年2月           1             2            0.2  2011      2
# 3     2011年3月           1           2.1            0.2  2011      3
# 4     2011年4月           1             2            0.2  2011      4
# 5     2011年5月         1.1           2.1            0.2  2011      5
# ..        ...         ...           ...            ...   ...    ...
# 115   2020年7月         1.3           4.7            0.1  2020      7
# 116   2020年8月         0.9           3.3            0.1  2020      8
# 117   2020年9月           1           2.7            0.1  2020      9
# 118  2020年10月         1.4           2.7            0.1  2020     10
# 119  2020年11月         1.7           3.1            0.1  2020     11
#
# [119 rows x 6 columns]

# %% [markdown]
# ---
#
# ## Summary
#
# In this lesson, we learn to process tabular data by using Pandas.
